# %% [markdown]
# # Box Plot

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
F=sns.load_dataset('tips')

# %%
F
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style="whitegrid")
sns.boxplot(x='day',y='total_bill',data=F,hue='time',showmeans=True , meanprops={"markeredgecolor":'w','marker':'+'}
            ,palette='vlag_r' )
plt.show()

# %% [markdown]
# # Cat Plot

# %% [raw]
# we can make different kind of plot using catplot
# 1 sripplot    2 violin
# 3 swarmplot   4 boxen
# 5 boxen       6 point
# 7 bar         8 count

# %%
var=sns.load_dataset('tips').head(20)

# %%
sns.catplot(x='tip', y='size', data=var,hue='sex',palette='vlag',kind='point')
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Seaborn Styling Plot

# %%
Data=sns.load_dataset('tips')

# %%
sns.set_style("darkgrid")
sns.barplot(x='day',y='total_bill',data=Data,saturation=1)
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(7,7))
sns.set_context('poster',font_scale=1
               
               )
sns.barplot(x='day',y='total_bill',data=Data,saturation=1)
sns.despine()
plt.show()
